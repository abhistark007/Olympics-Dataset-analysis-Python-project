# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# # 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("summer.csv")

# %%
df["City"].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
len(df["City"].unique())
# Out:
# 22

# %%
# 22 cities summer olympics is help so far

# %% [markdown]
# # 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Sport"].unique():
    data.append([i,len(df[(df['Sport']==i) & (df['Medal']=="Gold")])])
data
pd.DataFrame(data,columns = ['Sport','GoldMedal']).sort_values(by='GoldMedal', ascending=False).head().plot(x = 'Sport', y = 'GoldMedal', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %%
# Aquatics has most number of gold medals so far

# %% [markdown]
# # 3. Which sport is having most number of medals so far? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Sport"].unique():
    data.append([i,len(df[(df['Sport']==i) ])])
data
pd.DataFrame(data,columns = ['Sport','Medal']).sort_values(by='Medal', ascending=False).head().plot(x = 'Sport', y = 'Medal', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %%
# Aquatics has most number of medals so far

# %% [markdown]
# # 4. Which player has won most number of medals? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Athlete"].unique():
    data.append([i,len(df[(df['Athlete']==i) ])])
data
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 2],
#  ['DRIVAS, Dimitrios', 1],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 1],
#  ['CHOROPHAS, Efstathios', 2],
#  ['ANDREOU, Joannis', 1],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 1],
#  ['LANE, Francis', 1],
#  ['SZOKOLYI, Alajos', 1],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 4],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 1],
#  ['LERMUSIAUX, Albin', 1],
#  ['FLACK, Edwin', 3],
#  ['BLAKE, Arthur', 1],
#  ['GMELIN, Charles', 1],
#  ['JAMISON, Herbert', 1],
#  ['GOLEMIS, Dimitrios', 1],
#  ['DANI, Nandor', 1],
#  ['VERSIS, Sotirios', 2],
#  ['GARRETT, Robert', 6],
#  ['PARASKEVOPOULOS, Panagiotis', 1],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 5],
#  ['KELLNER, Gyula', 1],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 1],
#  ['DAMASKOS, Evangelos', 1],
#  ['THEODOROPOULOS, Ioannis', 1],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 1],
#  ['PAPASIDERIS, Georgios', 1],
# ...

# %%
pd.DataFrame(data,columns = ['Athlete','number of Medal']).sort_values(by='number of Medal', ascending=False).head().plot(x = 'Athlete', y = 'number of Medal', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
# PHELPS, Michael is the player who has won most number of medals

# %% [markdown]
# # 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Athlete"].unique():
    data.append([i,len(df[(df['Athlete']==i) & (df['Medal']=="Gold") ])])
data
# Out:
# [['HAJOS, Alfred', 2],
#  ['HERSCHMANN, Otto', 0],
#  ['DRIVAS, Dimitrios', 0],
#  ['MALOKINIS, Ioannis', 1],
#  ['CHASAPIS, Spiridon', 0],
#  ['CHOROPHAS, Efstathios', 0],
#  ['ANDREOU, Joannis', 0],
#  ['NEUMANN, Paul', 1],
#  ['PEPANOS, Antonios', 0],
#  ['LANE, Francis', 0],
#  ['SZOKOLYI, Alajos', 0],
#  ['BURKE, Thomas', 2],
#  ['HOFMANN, Fritz', 2],
#  ['CURTIS, Thomas', 1],
#  ['GOULDING, Grantley', 0],
#  ['LERMUSIAUX, Albin', 0],
#  ['FLACK, Edwin', 2],
#  ['BLAKE, Arthur', 0],
#  ['GMELIN, Charles', 0],
#  ['JAMISON, Herbert', 0],
#  ['GOLEMIS, Dimitrios', 0],
#  ['DANI, Nandor', 0],
#  ['VERSIS, Sotirios', 0],
#  ['GARRETT, Robert', 2],
#  ['PARASKEVOPOULOS, Panagiotis', 0],
#  ['CLARK, Ellery', 2],
#  ['CONNOLLY, James', 1],
#  ['KELLNER, Gyula', 0],
#  ['LOUIS, Spyridon', 1],
#  ['VASILAKOS, Kharilaos', 0],
#  ['DAMASKOS, Evangelos', 0],
#  ['THEODOROPOULOS, Ioannis', 0],
#  ['HOYT, William Welles', 1],
#  ['TYLER, Albert', 0],
#  ['PAPASIDERIS, Georgios', 0],
# ...

# %%
pd.DataFrame(data,columns = ['Athlete','number of GoldMedal']).sort_values(by='number of GoldMedal', ascending=False).head().plot(x = 'Athlete', y = 'number of GoldMedal', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Athlete'>

# %%
# PHELPS, Michael has won most number of gold medals

# %% [markdown]
# # 6. In which year India won first Gold Medal in Summer Olympics?

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Year"].unique():
    data.append([i,len(df[(df['Country']=="IND") & (df['Medal']=="Gold") & (df["Year"]==i) ])])
data
# Out:
# [[1896, 0],
#  [1900, 0],
#  [1904, 0],
#  [1908, 0],
#  [1912, 0],
#  [1920, 0],
#  [1924, 0],
#  [1928, 15],
#  [1932, 11],
#  [1936, 19],
#  [1948, 20],
#  [1952, 14],
#  [1956, 17],
#  [1960, 0],
#  [1964, 15],
#  [1968, 0],
#  [1972, 0],
#  [1976, 0],
#  [1980, 16],
#  [1984, 0],
#  [1988, 0],
#  [1992, 0],
#  [1996, 0],
#  [2000, 0],
#  [2004, 0],
#  [2008, 1],
#  [2012, 0]]

# %%
# in 1928 india won first Gold Medal in Summer Olympics

# %% [markdown]
# # 7. Which event is most popular in terms on number of players? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Event"].unique():
    data.append([i,len(df[(df['Event']==i)])])
data
# Out:
# [['100M Freestyle', 148],
#  ['100M Freestyle For Sailors', 3],
#  ['1200M Freestyle', 3],
#  ['400M Freestyle', 144],
#  ['100M', 142],
#  ['110M Hurdles', 80],
#  ['1500M', 114],
#  ['400M', 119],
#  ['800M', 126],
#  ['Discus Throw', 141],
#  ['High Jump', 151],
#  ['Long Jump', 132],
#  ['Marathon', 105],
#  ['Pole Vault', 100],
#  ['Shot Put', 132],
#  ['Triple Jump', 96],
#  ['Individual Road Race', 76],
#  ['100KM', 5],
#  ['10KM', 9],
#  ['12-Hour Race', 2],
#  ['1KM Time Trial', 57],
#  ['Sprint Indivual', 69],
#  ['Foil Individual', 141],
#  ['Foil, Masters', 5],
#  ['Sabre Individual', 90],
#  ['Horizontal Bar', 72],
#  ['Parallel Bars', 72],
#  ['Pommel Horse', 69],
#  ['Rings', 73],
#  ['Rope Climbing', 13],
#  ['Team, Horizontal Bar', 11],
#  ['Team, Parallel Bars', 19],
#  ['Vault', 123],
#  ['25M Army Pistol', 3],
#  ['25M Rapid Fire Pistol (60 Shots)', 69],
#  ['50M Pistol (60 Shots)', 66],
#  ['Army Rifle, 200M', 3],
#  ['Army Rifle, 300M', 3],
#  ['Doubles', 318],
# ...

# %%
pd.DataFrame(data,columns = ['Event','number of Players']).sort_values(by='number of Players', ascending=False).head().plot(x = 'Event', y = 'number of Players', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Event'>

# %%
# Football is most popular in terms of number of players

# %% [markdown]
# # 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
data=[]
for i in df["Sport"].unique():
    data.append([i,len(df[(df['Sport']==i) & (df["Medal"]=="Gold") & (df["Gender"]=="Women")])])
data
# Out:
# [['Aquatics', 589],
#  ['Athletics', 389],
#  ['Cycling', 45],
#  ['Fencing', 108],
#  ['Gymnastics', 268],
#  ['Shooting', 43],
#  ['Tennis', 38],
#  ['Weightlifting', 28],
#  ['Wrestling', 12],
#  ['Archery', 39],
#  ['Basque Pelota', 0],
#  ['Cricket', 0],
#  ['Croquet', 0],
#  ['Equestrian', 51],
#  ['Football', 86],
#  ['Golf', 1],
#  ['Polo', 0],
#  ['Rowing', 217],
#  ['Rugby', 0],
#  ['Sailing', 38],
#  ['Tug of War', 0],
#  ['Boxing', 3],
#  ['Lacrosse', 0],
#  ['Roque', 0],
#  ['Hockey', 144],
#  ['Jeu de paume', 0],
#  ['Rackets', 0],
#  ['Skating', 4],
#  ['Water Motorsports', 0],
#  ['Modern Pentathlon', 4],
#  ['Ice Hockey', 0],
#  ['Basketball', 120],
#  ['Canoe / Kayak', 76],
#  ['Handball', 142],
#  ['Judo', 42],
#  ['Volleyball', 166],
#  ['Table Tennis', 23],
#  ['Badminton', 23],
#  ['Baseball', 0],
#  ['Softball', 60],
#  ['Taekwondo', 16],
#  ['Triathlon', 4],
#  ['Canoe', 9]]

# %%
pd.DataFrame(data,columns = ['Sport','number of Female gold medalist']).sort_values(by='number of Female gold medalist', ascending=False).head().plot(x = 'Sport', y = 'number of Female gold medalist', kind = 'bar', figsize = (5,5))
# Out:
# <AxesSubplot:xlabel='Sport'>

# %%
# Aquatics is the sport having most number of Women gold medalist
